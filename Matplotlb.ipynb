# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2,4]
y=[8,9,10]

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %%
data = {
    "salary": [
        22000, 24000, 25000, 26000, 27000,
        28000, 29000, 30000, 31000, 32000,
        33000, 34000, 35000, 36000, 37000,
        38000, 39000, 40000, 42000, 45000,
        47000, 48000, 50000, 52000, 55000,
        58000, 60000, 62000, 65000, 70000,
        75000, 80000, 85000, 90000, 95000,
        100000
    ]
}

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    salary
# 0   22000
# 1   24000
# 2   25000
# 3   26000
# 4   27000

# %%
#line plot

plt.plot(df["salary"],color="red",marker="o",linestyle=":" ,linewidth="2" )
plt.grid()
plt.show()

# %%
#histogram
plt.hist(df["salary"],bins=5,color="green")
plt.show()

# %%
#boxplot
plt.boxplot(df["salary"])
plt.show()

# %%
df.count()
plt.boxplot(df["salary"])
plt.show()

# %%
df.loc[20]=[0]
plt.boxplot(df["salary"])
plt.show()

# %%
df["salary"]
# Out:
# 0      22000
# 1      24000
# 2      25000
# 3      26000
# 4      27000
# 5      28000
# 6      29000
# 7      30000
# 8      31000
# 9      32000
# 10     33000
# 11     34000
# 12     35000
# 13     36000
# 14     37000
# 15     38000
# 16     39000
# 17     40000
# 18     42000
# 19     45000
# 20         0
# 21     48000
# 22     50000
# 23     52000
# 24     55000
# 25     58000
# 26     60000
# 27     62000
# 28     65000
# 29     70000
# 30     75000
# 31     80000
# 32     85000
# 33     90000
# 34     95000
# 35    100000
# Name: salary, dtype: int64

# %%
df.drop(index=20,inplace=True)
df
# Out:
#     salary
# 0    22000
# 1    24000
# 2    25000
# 3    26000
# 4    27000
# 5    28000
# 6    29000
# 7    30000
# 8    31000
# 9    32000
# 10   33000
# 11   34000
# 12   35000
# 13   36000
# 14   37000
# 15   38000
# 16   39000
# 17   40000
# 18   42000
# 19   45000
# 21   48000
# 22   50000
# 23   52000
# 24   55000
# 25   58000
# 26   60000
# 27   62000
# 28   65000
# 29   70000
# 30   75000
# 31   80000
# 32   85000
# 33   90000
# 34   95000
# 35  100000

# %%
#univaraite : categorial
df["dept"]=[
        "Finance", "HR", "IT", "Marketing", "Sales",
        
    ]*7
df
# Out:
#     salary       dept
# 0    22000    Finance
# 1    24000         HR
# 2    25000         IT
# 3    26000  Marketing
# 4    27000      Sales
# 5    28000    Finance
# 6    29000         HR
# 7    30000         IT
# 8    31000  Marketing
# 9    32000      Sales
# 10   33000    Finance
# 11   34000         HR
# 12   35000         IT
# 13   36000  Marketing
# 14   37000      Sales
# 15   38000    Finance
# 16   39000         HR
# 17   40000         IT
# 18   42000  Marketing
# 19   45000      Sales
# 21   48000    Finance
# 22   50000         HR
# 23   52000         IT
# 24   55000  Marketing
# 25   58000      Sales
# 26   60000    Finance
# 27   62000         HR
# 28   65000         IT
# 29   70000  Marketing
# 30   75000      Sales
# 31   80000    Finance
# 32   85000         HR
# 33   90000         IT
# 34   95000  Marketing
# 35  100000      Sales

# %%
#pie chart
count=df["dept"].value_counts()
count
# Out:
# dept
# Finance      7
# HR           7
# IT           7
# Marketing    7
# Sales        7
# Name: count, dtype: int64

# %%
plt.pie(count,labels=count.index,autopct="%1.2f",explode=[0,0.1,0,0.1,0])
plt.axis("equal")
plt.show()

# %%
#count plot
plt.bar(count.index,count,color=["green","purple","red"])
plt.show()

# %%
#bivariate -numerical-numerical
df.head()
# Out:
#    salary       dept
# 0   22000    Finance
# 1   24000         HR
# 2   25000         IT
# 3   26000  Marketing
# 4   27000      Sales

# %%
df["Age"] = [
    22, 24, 25, 23, 26,
    27, 28, 29, 30, 24,
    25, 31, 32, 26, 27,
    28, 29, 33, 34, 35,
    23, 24, 26, 27, 28,
    29, 30, 31, 32, 33,
    25, 26, 27, 28, 29
]
df.head()
# Out:
#    salary       dept  Age
# 0   22000    Finance   22
# 1   24000         HR   24
# 2   25000         IT   25
# 3   26000  Marketing   23
# 4   27000      Sales   26

# %%
#scatter plot
plt.scatter(df["Age"],df["salary"])
plt.show()

# %%
#line plot
sort_age=df.sort_values("Age")
plt.plot(sort_age["Age"],df["salary"],color="red",marker="*",linestyle=":",linewidth="2")
plt.grid()
plt.show()

# %%
plt.bar(sort_age["Age"],df["salary"],color="green",align="edge")
plt.show()

# %%
#bivariate : Numerical-categorial
hr_sal = df[df["dept"] == "HR"]["salary"]
it_sal = df[df["dept"] == "IT"]["salary"]
finance_sal = df[df["dept"] == "Finance"]["salary"]
marketing_sal = df[df["dept"] == "Marketing"]["salary"]
sales_sal = df[df["dept"] == "Sales"]["salary"]

# %%
#boxplot
plt.boxplot( [hr_sal,it_sal,finance_sal,marketing_sal,sales_sal],labels=["Hr","it","finance","marketing","sales"])
plt.show()
# Out:
# /tmp/ipykernel_9986/3084076112.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot( [hr_sal,it_sal,finance_sal,marketing_sal,sales_sal],labels=["Hr","it","finance","marketing","sales"])

# %%
#pie chart
salary_bydept=df.groupby("dept")["salary"].sum()
salary_bydept
# Out:
# dept
# Finance      309000
# HR           323000
# IT           337000
# Marketing    355000
# Sales        374000
# Name: salary, dtype: int64

# %%
plt.pie(salary_bydept,labels=salary_bydept.index,autopct="%1.0f",shadow=True)
plt.axis("equal")
plt.show()

# %%
hr_mean = sum(hr_sal) / len(hr_sal)
it_mean = sum(it_sal) / len(it_sal)
finance_mean = sum(finance_sal) / len(finance_sal)
marketing_mean = sum(marketing_sal) / len(marketing_sal)
sales_mean = sum(sales_sal) / len(sales_sal)

# %%
plt.bar(["Hr","it","finance","marketing","sales"],[hr_mean,it_mean,finance_mean,marketing_mean,sales_mean],color="green")
plt.grid()
plt.show()

# %%
#multivariate analysis: 3numerical
df["experience"] = [
    0.5, 1, 1, 1.5, 2,
    2, 2.5, 3, 3, 3.5,
    4, 4.5, 5, 5.5, 6,
    6.5, 7, 7.5, 8, 8.5,
    9, 9.5, 10, 11, 12,
    13, 14, 15, 16, 17,
    18, 20, 22, 24, 26
]
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 2
#       1 #multivariate analysis: 3numerical
# ----> 2 df["experience"] = [
#       3     0.5, 1, 1, 1.5, 2,
#       4     2, 2.5, 3, 3, 3.5,
#       5     4, 4.5, 5, 5.5, 6,
#
# File ~/python 2026/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4668             # Column to set is duplicated
#    4669             self._setitem_array([key], value)
#    4670         else:
#    4671             # set column
# -> 4672             self._set_item(key, value)
#
# File ~/python 2026/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4872, in DataFrame._set_item(self, key, value)
#    4868
#    4869         Series/TimeSeries will be conformed to the DataFrames index to
#    4870         ensure homogeneity.
#    4871         """
# ...

# %%
#bubble plot
plt.scatter(df["Age"],df["salary"],s=df["experience"]*20,color="skyblue")
plt.title("Age vs Salary vs Experience")
plt.xlabel( "Age")
plt.ylabel("Salary")
plt.show()

# %%
#numerical-2
#categorial-1
color_map = {
    "HR": "red",
    "IT": "blue",
    "Finance": "green",
    "Sales": "orange",
    "Marketing":"black"
}
plt.scatter(df["Age"],df["salary"],c=df["dept"].map(color_map).fillna("gray"))
plt.title("Age vs Salary vs dept")
plt.xlabel( "Age")
plt.ylabel("Salary")
plt.show()

# %%
color_map = {
    "HR": "red",
    "IT": "blue",
    "Finance": "green",
    "Sales": "orange",
    "Marketing": "black"
}

for dept, color in color_map.items():
    
    subset = df[df["dept"] == dept]
    
    plt.scatter(
        subset["Age"],
        subset["salary"],
        color=color,
        label=dept
    )

plt.title("Age vs Salary vs Dept")
plt.xlabel("Age")
plt.ylabel("Salary")

plt.legend()

plt.show()

# %%
#object oriented API
fig, axs = plt.subplots(1,3,figsize=(15,5))
#line plt
axs[0].plot(sort_age["Age"],df["salary"],color="red",marker="*",linewidth="2")
axs[0].grid()
axs[0].set_title("line plot")
axs[0].set_xlabel("Age")
axs[0].set_ylabel("salary")

#histogram
axs[1].hist(df["salary"],bins=5,color="green")
axs[1].set_title("histogram")
axs[1].set_xlabel("salary")
axs[1].set_ylabel("Frequency")

#boxplot
axs[2].boxplot(df["salary"])

axs[2].set_title("Box Plot")
axs[2].set_ylabel("Salary")
plt.savefig("mutipleplots.png")
plt.show()

# %%
data2 = {
    "Year": [2019, 2020, 2021, 2022, 2023, 2024],
    
    "Sales": [50000, 62000, 70000, 85000, 95000, 110000],
    
    "Expenses": [30000, 35000, 42000, 50000, 58000, 65000]
}
df = pd.DataFrame(data2)

df["Profit"] = df["Sales"] - df["Expenses"]
df
# Out:
#    Year   Sales  Expenses  Profit
# 0  2019   50000     30000   20000
# 1  2020   62000     35000   27000
# 2  2021   70000     42000   28000
# 3  2022   85000     50000   35000
# 4  2023   95000     58000   37000
# 5  2024  110000     65000   45000

# %%
plt.plot(df["Year"],df["Sales"],label="Sales")
plt.plot(df["Year"],df["Expenses"],label="Expenses")
plt.plot(df["Year"],df["Profit"],label="Profit")

plt.legend()
plt.show()

# %%
#3d plot
ax=plt.axes(projection="3d")
ax.scatter(df["Expenses"],df["Sales"],df["Profit"])
plt.show()

# %%
import plotly.express as px
